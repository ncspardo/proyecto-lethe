# %%
import pandas as pd
from sklearn.preprocessing import StandardScaler

# %%
basedir = "/bigd/code/ncspardo/proyecto-lethe/Lethe"
files_dict = {
    "healthy" : 0,
    "narco"   : 1,
    "plm"     : 2,
    "sdb"     : 3, 
    "nfle"    : 4,
    "rbd"     : 5
}

columns = []
for c in range(1024):
    columns.append("f"+str(c))
columns.append('phase')

df = {}
for key in files_dict:
    filepath = basedir + "/raw_data/bal_" + key + ".csv"
    df[key] = pd.read_csv(filepath, names=columns)
    df[key]['target'] = files_dict[key]
    df[key]['target'] = df[key]['target'].astype(int)
    df[key].dropna()
    print(key, " shape ", df[key].shape)
# Out:
# healthy  shape  (9306, 1026)
# narco  shape  (9558, 1026)
# plm  shape  (17934, 1026)
# sdb  shape  (1566, 1026)
# nfle  shape  (75576, 1026)
# rbd  shape  (44100, 1026)

# %%
df['rbd'].head()
# Out:
#           f0         f1         f2         f3         f4         f5  \
# 0   7.738095   7.738095   7.921245   8.226496   8.287546   7.921245
# 1 -13.202076 -12.744200 -11.217949  -8.989621  -7.097070  -5.753968
# 2  -6.364469  -6.608669  -7.524420  -8.867521 -10.088523 -11.126374
# 3  12.622100  14.209402  15.735653  16.712454  17.231380  17.567155
# 4 -19.948107 -18.025031 -16.040904 -14.239927 -12.805250 -11.614774
#
#           f6         f7         f8         f9  ...      f1016      f1017  \
# 0   7.707570   7.982295   8.440171   8.775946  ... -11.523199 -13.659951
# 1  -4.746642  -4.349817  -4.227717  -3.922466  ...  -0.442613  -1.877289
# 2 -11.981074 -12.408425 -12.164225 -11.584249  ...  11.706349  11.492674
# 3  17.628205  17.506105  17.414530  17.139805  ... -22.542735 -23.153236
# 4 -10.882173 -10.851648 -10.943223 -10.790598  ...   4.532967   4.594017
#
#        f1018      f1019      f1020      f1021      f1022      f1023  phase  \
# 0 -14.239927 -13.659951 -12.683150 -12.255800 -12.377900 -12.896825    0.0
# 1  -3.281441  -4.746642  -5.876068  -6.394994  -6.517094  -6.486569    0.0
# 2  11.126374  10.912698  11.065324  11.278999  11.278999  11.584249    0.0
# 3 -23.702686 -24.191087 -24.374237 -23.946886 -23.000611 -21.626984    0.0
# 4   4.685592   4.960317   5.570818   6.333944   6.852869   6.822344    0.0
#
#    target
# 0       5
# 1       5
# 2       5
# 3       5
# 4       5
#
# [5 rows x 1026 columns]

# %%
for key in files_dict:
    count = df[key].isna().sum().max()
    print(key, " nan values = ", count)
# Out:
# healthy  nan values =  0
# narco  nan values =  0
# plm  nan values =  0
# sdb  nan values =  0
# nfle  nan values =  0
# rbd  nan values =  0

# %%
from sklearn.preprocessing import RobustScaler
scaler = RobustScaler()

for key in files_dict:
    phase = df[key]['phase']
    target = df[key]['target']
    a = scaler.fit_transform(df[key].drop(['target','phase'], axis=1))
    df[key] = pd.DataFrame(a, columns = columns[:-1])
    df[key]['target'] = target
    df[key]['phase'] = phase

# %%
df['healthy'].head()
# Out:
#          f0        f1        f2        f3        f4        f5        f6  \
# 0 -0.588969 -0.572106 -0.551151 -0.489077 -0.384205 -0.279979 -0.189830
# 1  0.323256  0.301945  0.229824  0.159458  0.073639 -0.052998 -0.171598
# 2 -0.281359 -0.274399 -0.279831 -0.310355 -0.367129 -0.418094 -0.442937
# 3  0.181118  0.152562  0.090440 -0.018193 -0.116329 -0.133298 -0.099741
# 4 -0.204986 -0.217188 -0.176624 -0.119861 -0.066169 -0.048715 -0.067567
#
#          f7        f8        f9  ...     f1016     f1017     f1018     f1019  \
# 0 -0.132457 -0.109596 -0.126384  ...  0.017702  0.062399  0.129149  0.192677
# 1 -0.234761 -0.230827 -0.196597  ... -0.113200 -0.116192 -0.147445 -0.179244
# 2 -0.469522 -0.470043 -0.435323  ...  0.403968  0.434645  0.440183  0.406585
# 3 -0.079690 -0.079288 -0.097218  ...  0.462981  0.373321  0.267984  0.184078
# 4 -0.099074 -0.120420 -0.142587  ... -0.117492 -0.104358 -0.106548 -0.119049
#
#       f1020     f1021     f1022     f1023  target  phase
# 0  0.220086  0.235592  0.264650  0.300404       0    0.0
# 1 -0.210953 -0.238275 -0.259249 -0.274563       0    0.0
# 2  0.331877  0.266683  0.233324  0.207806       0    0.0
# 3  0.111520  0.047975 -0.020524 -0.119515       0    0.0
# 4 -0.151833 -0.188959 -0.222522 -0.237954       0    0.0
#
# [5 rows x 1026 columns]

# %% [markdown]
# ## Merge

# %%
all_df = pd.concat([df['healthy'], df['narco'], df['plm'], df['sdb'], df['nfle'], df['rbd']], axis=0)

# %%
all_df.shape
# Out:
# (158040, 1026)

# %%
target_0 = all_df[all_df['target'] == 0]
observations_0 = target_0.iloc[0]

# %%
len(all_df[all_df['target'] == 0])
# Out:
# 9306

# %%
target_1 = all_df[all_df['target'] == 1]
observations_1 = target_1.iloc[0]

# %%
import numpy as np
import matplotlib.pyplot as plt

x = np.linspace(1,1025,1024)
plt.plot(x,observations_0[0:-2], label = "Healthy", color='red')
plt.plot(x,observations_1[0:-2], label = "Narco", color='blue')
plt.legend()

# %%
all_df.head(20)
# Out:
#           f0        f1        f2        f3        f4        f5        f6  \
# 0  -0.588969 -0.572106 -0.551151 -0.489077 -0.384205 -0.279979 -0.189830
# 1   0.323256  0.301945  0.229824  0.159458  0.073639 -0.052998 -0.171598
# 2  -0.281359 -0.274399 -0.279831 -0.310355 -0.367129 -0.418094 -0.442937
# 3   0.181118  0.152562  0.090440 -0.018193 -0.116329 -0.133298 -0.099741
# 4  -0.204986 -0.217188 -0.176624 -0.119861 -0.066169 -0.048715 -0.067567
# 5  -0.232565 -0.233080 -0.262807 -0.297513 -0.321238 -0.364561 -0.420415
# 6  -0.095731 -0.068865 -0.026600  0.031036  0.090715  0.131156  0.163018
# 7  -0.197561 -0.209772 -0.195776 -0.179792 -0.178228 -0.170771 -0.137278
# 8  -0.073456 -0.029665 -0.009576  0.023544  0.083244  0.166488  0.248817
# 9   0.356138  0.325253  0.290471  0.251495  0.209178  0.169700  0.139423
# 3   0.111520  0.047975 -0.020524 -0.119515       0    0.0
# 4  -0.151833 -0.188959 -0.222522 -0.237954       0    0.0
# 5   0.009404 -0.017423 -0.052930 -0.088291       0    0.0
# 6  -0.174406 -0.126777 -0.129625 -0.164738       0    0.0
# 7  -0.273298 -0.266150 -0.226843 -0.151817       0    0.0
# 8   0.351225  0.368532  0.396435  0.394078       0    0.0
# 9   0.420020  0.328865  0.243046  0.203499       0    0.0
# 10  0.062074  0.001875 -0.126384 -0.263795       0    0.0
# 11  0.438293  0.429642  0.436403  0.433917       0    0.0
# 12  0.019078  0.005091  0.009722  0.040915       0    0.0
# 13  0.404971  0.368532  0.311099  0.246568       0    0.0
# 14 -0.201279 -0.201824 -0.178234 -0.148587       0    0.0
# 15  0.393147  0.357811  0.311099  0.251952       0    0.0
# 16  0.337252  0.302062  0.289495  0.321938       0    0.0
# 17 -0.220627 -0.207185 -0.184715 -0.160431       0    0.0
# 18  0.119045  0.106940  0.086416  0.060296       0    0.0
# 19 -0.205578 -0.061379  0.068053  0.193809       0    0.0
#
# [20 rows x 1026 columns]

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.model_selection import cross_validate
from sklearn.model_selection import train_test_split

# Create the feature set
X = all_df.drop('target', axis=1)
y = all_df['target']
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2)

# Instanciate model
model = LogisticRegression(max_iter=300)

cv_results = cross_validate(model, X_train, y_train, cv=5)

cv_results['test_score'].mean()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In [51], line 13
#      10 # Instanciate model
#      11 model = LogisticRegression(max_iter=300)
# ---> 13 cv_results = cross_validate(model, X_train, y_train, cv=5)
#      15 cv_results['test_score'].mean()
#
# File ~/.local/lib/python3.10/site-packages/sklearn/utils/_param_validation.py:211, in validate_params.<locals>.decorator.<locals>.wrapper(*args, **kwargs)
#     205 try:
#     206     with config_context(
#     207         skip_parameter_validation=(
#     208             prefer_skip_nested_validation or global_skip_validation
#     209         )
#     210     ):
# --> 211         return func(*args, **kwargs)
#     212 except InvalidParameterError as e:
#     213     # When the function is just a wrapper around an estimator, we allow
#     214     # the function to delegate validation to the estimator, but we replace
#     215     # the name of the estimator by the name of the function in the error
#     216     # message to avoid confusion.
#     217     msg = re.sub(
#     218         r"parameter of \w+ must be",
#     219         f"parameter of {func.__qualname__} must be",
#     220         str(e),
#     221     )
#
# File ~/.local/lib/python3.10/site-packages/sklearn/model_selection/_validation.py:328, in cross_validate(estimator, X, y, groups, scoring, cv, n_jobs, verbose, fit_params, pre_dispatch, return_train_score, return_estimator, return_indices, error_score)
#     308 parallel = Parallel(n_jobs=n_jobs, verbose=verbose, pre_dispatch=pre_dispatch)
#     309 results = parallel(
#     310     delayed(_fit_and_score)(
#     311         clone(estimator),
#    (...)
#     325     for train, test in indices
#     326 )
# --> 328 _warn_or_raise_about_fit_failures(results, error_score)
#     330 # For callable scoring, the return type is only know after calling. If the
#     331 # return type is a dictionary, the error scores can now be inserted with
#     332 # the correct key.
#     333 if callable(scoring):
#
# File ~/.local/lib/python3.10/site-packages/sklearn/model_selection/_validation.py:414, in _warn_or_raise_about_fit_failures(results, error_score)
#     407 if num_failed_fits == num_fits:
#     408     all_fits_failed_message = (
#     409         f"\nAll the {num_fits} fits failed.\n"
#     410         "It is very likely that your model is misconfigured.\n"
#     411         "You can try to debug the error by setting error_score='raise'.\n\n"
#     412         f"Below are more details about the failures:\n{fit_errors_summary}"
#     413     )
# --> 414     raise ValueError(all_fits_failed_message)
#     416 else:
#     417     some_fits_failed_message = (
#     418         f"\n{num_failed_fits} fits failed out of a total of {num_fits}.\n"
#     419         "The score on these train-test partitions for these parameters"
#    (...)
#     423         f"Below are more details about the failures:\n{fit_errors_summary}"
#     424     )
#
# ValueError:
# All the 5 fits failed.
# It is very likely that your model is misconfigured.
# You can try to debug the error by setting error_score='raise'.
#
# Below are more details about the failures:
# --------------------------------------------------------------------------------
# 2 fits failed with the following error:
# Traceback (most recent call last):
#   File "/home/alejandra/.local/lib/python3.10/site-packages/sklearn/model_selection/_validation.py", line 729, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "/home/alejandra/.local/lib/python3.10/site-packages/sklearn/base.py", line 1152, in wrapper
#     return fit_method(estimator, *args, **kwargs)
#   File "/home/alejandra/.local/lib/python3.10/site-packages/sklearn/linear_model/_logistic.py", line 1208, in fit
#     X, y = self._validate_data(
#   File "/home/alejandra/.local/lib/python3.10/site-packages/sklearn/base.py", line 622, in _validate_data
#     X, y = check_X_y(X, y, **check_params)
#   File "/home/alejandra/.local/lib/python3.10/site-packages/sklearn/utils/validation.py", line 1146, in check_X_y
#     X = check_array(
#   File "/home/alejandra/.local/lib/python3.10/site-packages/sklearn/utils/validation.py", line 915, in check_array
#     array = _asarray_with_order(array, order=order, dtype=dtype, xp=xp)
#   File "/home/alejandra/.local/lib/python3.10/site-packages/sklearn/utils/_array_api.py", line 380, in _asarray_with_order
#     array = numpy.asarray(array, order=order, dtype=dtype)
# numpy.core._exceptions._ArrayMemoryError: Unable to allocate 791. MiB for an array with shape (101145, 1025) and data type float64
#
# --------------------------------------------------------------------------------
# 3 fits failed with the following error:
# Traceback (most recent call last):
#   File "/home/alejandra/.local/lib/python3.10/site-packages/sklearn/model_selection/_validation.py", line 729, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "/home/alejandra/.local/lib/python3.10/site-packages/sklearn/base.py", line 1152, in wrapper
#     return fit_method(estimator, *args, **kwargs)
#   File "/home/alejandra/.local/lib/python3.10/site-packages/sklearn/linear_model/_logistic.py", line 1208, in fit
#     X, y = self._validate_data(
#   File "/home/alejandra/.local/lib/python3.10/site-packages/sklearn/base.py", line 622, in _validate_data
#     X, y = check_X_y(X, y, **check_params)
#   File "/home/alejandra/.local/lib/python3.10/site-packages/sklearn/utils/validation.py", line 1146, in check_X_y
#     X = check_array(
#   File "/home/alejandra/.local/lib/python3.10/site-packages/sklearn/utils/validation.py", line 915, in check_array
#     array = _asarray_with_order(array, order=order, dtype=dtype, xp=xp)
#   File "/home/alejandra/.local/lib/python3.10/site-packages/sklearn/utils/_array_api.py", line 380, in _asarray_with_order
#     array = numpy.asarray(array, order=order, dtype=dtype)
# numpy.core._exceptions._ArrayMemoryError: Unable to allocate 791. MiB for an array with shape (101146, 1025) and data type float64

# %%
y_pred = model.predict(X_test)

# %% [markdown]
# ## Accuracy score

# %%
from sklearn.metrics import accuracy_score

correct_pred_ratio = accuracy_score(y_test, y_pred)
correct_pred_ratio

# %% [markdown]
# ## Precision score

# %% [markdown]
# from sklearn.metrics import precision_score
# correct_detection_ratio = precision_score(y_test,y_pred)
# correct_detection_ratio

# %% [markdown]
# ## ConfusionMatrix from predictions

# %%
from sklearn.metrics import ConfusionMatrixDisplay

ConfusionMatrixDisplay.from_predictions(y_test, y_pred)
plt.show()

# %% [markdown]
# ## ConfusionMatrix from estimator

# %%
ConfusionMatrixDisplay.from_estimator(model, X_test, y_test)
plt.show()

# %% [markdown]
# ## KNN

# %%
from sklearn.neighbors import KNeighborsClassifier
knn = KNeighborsClassifier(n_neighbors = 3)
knn.fit(X_train,y_train)
y_pred = knn.predict(X_test)

# %%
flag_ratio = recall_score(y_test,y_pred)
flag_ratio
